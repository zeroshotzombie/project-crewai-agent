# %%
from dotenv import load_dotenv 
load_dotenv()

from crewai import LLM

llm = LLM(
    model = "gemini/gemini-2.0-flash",
    tempreture=0.1
)

# %%
from crewai import Agent, Task, Crew

research_agent = Agent(
    role="Research Specialization Agent",
    goal="Research interesting facts about the topic: {topic}",
    backstory="You are an expert at finding relevant and factual data.",
    verbose=True,
    llm=llm
)

writer_agent = Agent(
    role="Creative Writer",
    goal="Write a short blog summary using the response",
    backstory="You are skilled at writing engaging summaries based on provided contents",
    llm=llm,
    verbose=True
)

# %%
Task1 = Task(
    description="find 3-5 interesting and recent facts about {topic}.",
    expected_output="A bullet list of 3-5 facts",
    agent=research_agent,
)

Task2 = Task(
    description="Write a 100 word blog post summary about {topic} using the facts from the research",
    expected_output="A blog post summary",
    agent=writer_agent,
    context=[Task1],
)

crew = Crew(
    agents=[research_agent, writer_agent],
    tasks=[Task1, Task2],
    verbose=True,
)

crew.kickoff(inputs={"topic":"The future of electrical vehicles"})
# Out:
# ╭──────────────────────────────────────────── Crew Execution Started ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: d86be203-3f99-4d1c-9ff4-506da8fcbd22                                                                       │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Research Specialization Agent                                                                           │
# │                                                                                                                 │
# │  Task: find 3-5 interesting and recent facts about The future of electrical vehicles.                           │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Research Specialization Agent                                                                           │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  *   **Global EV sales are projected to continue their rapid growth:** According to the International Energy    │
# │  Agency (IEA), electric car sales hit a record 14% of all new cars sold globally in 2022. They forecast that    │
# │  electric cars will account for around 35% of all new car sales by 2030. [Source: IEA, Global EV Outlook 2023]  │
# │                                                                                                                 │
# │  *   **Battery technology is rapidly advancing:** Innovations in battery technology are leading to increased    │
# │  range, faster charging times, and lower costs for EVs. Solid-state batteries are a particularly promising      │
# │  area of development, with the potential to offer significantly higher energy density and improved safety       │
# │  compared to current lithium-ion batteries. Several companies are aiming to commercialize solid-state           │
# │  batteries in the coming years. [Source: Various reports from research institutions and automotive news         │
# │  outlets]                                                                                                       │
# │                                                                                                                 │
# │  *   **Governments worldwide are implementing policies to support EV adoption:** Many countries and regions     │
# │  have set targets for phasing out internal combustion engine vehicles and are offering incentives such as tax   │
# │  credits and subsidies to encourage the purchase of EVs. Regulations are also being introduced to promote the   │
# │  development of charging infrastructure and reduce emissions from the transportation sector. [Source: Policies  │
# │  from individual countries, like the EU's "Fit for 55" package]                                                 │
# │                                                                                                                 │
# │  *   **The electric vehicle market is diversifying:** While passenger cars have been the primary focus of the   │
# │  EV revolution so far, other types of electric vehicles, such as buses, trucks, and vans, are also gaining      │
# │  traction. The electrification of commercial vehicles is expected to play a significant role in reducing        │
# │  emissions from the transportation sector, particularly in urban areas. [Source: Market research reports from   │
# │  companies like BloombergNEF and IDTechEx]                                                                      │
# │                                                                                                                 │
# │  *   **The charging infrastructure is expanding, but challenges remain:** The availability of charging          │
# │  stations is crucial for supporting the widespread adoption of EVs. While the charging infrastructure is        │
# │  growing rapidly, there are still challenges to overcome, such as ensuring equitable access to charging in      │
# │  rural areas and multi-unit dwellings and deploying fast chargers to reduce charging times. [Source: Reports    │
# │  on charging infrastructure deployment from organizations like the US Department of Energy and the European     │
# │  Alternative Fuels Observatory]                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────────── Task Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: 82511b9f-cc6c-4cf4-8034-27d372c70338                                                                     │
# │  Agent: Research Specialization Agent                                                                           │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Creative Writer                                                                                         │
# │                                                                                                                 │
# │  Task: Write a 100 word blog post summary about The future of electrical vehicles using the facts from the      │
# │  research                                                                                                       │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Creative Writer                                                                                         │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  **The Road Ahead: A Glimpse into the Future of Electric Vehicles**                                             │
# │                                                                                                                 │
# │  The electric vehicle (EV) revolution is charging forward! Global EV sales hit a record 14% in 2022, and        │
# │  projections estimate 35% of new car sales will be electric by 2030. This growth is fueled by advancements in   │
# │  battery technology, promising longer ranges and faster charging, with solid-state batteries on the horizon.    │
# │  Governments worldwide are accelerating EV adoption through incentives and regulations, while the EV market     │
# │  diversifies beyond passenger cars to include buses, trucks, and vans. Expanding charging infrastructure is     │
# │  crucial, though challenges remain in ensuring equitable access and deploying fast chargers. The future of      │
# │  transportation is undoubtedly electric, paving the way for a greener and more sustainable world.               │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
