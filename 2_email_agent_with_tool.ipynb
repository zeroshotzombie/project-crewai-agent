# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from crewai import LLM
import os
llm = LLM(
    model="gemini/gemini-2.0-flash",
    api_key=os.getenv("GEMINI_API_KEY"),
    temperature=0.1
)
llm.call("who invented the light bulb")
# Out:
# "The invention of the light bulb is often attributed to **Thomas Edison**, and he certainly played a crucial role in its development and commercialization. However, it's more accurate to say that he **perfected and popularized** the incandescent light bulb.\n\nHere's a more nuanced breakdown:\n\n*   **Early Inventors:** Many inventors before Edison experimented with electric lighting. Some notable figures include:\n\n    *   **Humphry Davy (early 1800s):** Created the first electric light by connecting a powerful battery to a charcoal electrode. This was more of a demonstration than a practical light source.\n    *   **Warren de la Rue (1840):** Developed a light bulb using a platinum filament, but the high cost of platinum made it impractical.\n    *   **Joseph Swan (1878):** A British physicist who independently developed a working light bulb around the same time as Edison. He used a treated cotton thread for the filament.\n\n*   **Thomas Edison's Contribution:** Edison's key contr
# ...

# %%
original_email = """
Hey team, how are you doing. I am checking on SDS and BTS whats the status on our last call?
"""

from crewai.tools import BaseTool

class ReplaceJargonTool(BaseTool):
    name: str = "replace_jargon"
    description: str = "Replace Jargon with specific terms"
    
    def _run(self, email: str) -> str:
        replacement = {
            "SDS": "Strategic Data Solution",
            "BTS": "Balanced Technology System"
        }
        suggestions = []
        email_lower = email.lower()
        for jargon, replacement in replacement.items():
            suggestions.append(f"consider replacing {jargon} with {replacement}")
        
        return "\n".join(suggestions) if suggestions else "No Jargon"
    
jt = ReplaceJargonTool()
jt.run(original_email)
# Out:
# Using Tool: replace_jargon
# 'consider replacing SDS with Strategic Data Solution\nconsider replacing BTS with Balanced Technology System'

# %%
from crewai import Agent, Task, Crew

email_assistant = Agent(
    role = "Email Assistant Agent",
    goal = "Improve emails and make them sound professional and clear",
    backstory = "A highly experienced communication expert skilled in professional email writing",
    tools = [jt],
    verbose = True,
    llm = llm
)

original_email = """
Hey team, how are you doing. I am checking on SDS and BTS whats the status on our last call?
"""

email_task = Task(
    description = f"""Take the following rough email and rewrite it into a professional and polished version. Expand abbreviations:
    '''{original_email}''""",
    agent = email_assistant,
    expected_output = "A professional written email with proper formatting and contents of email."
)

crew = Crew(
    agents = [email_assistant],
    tasks = [email_task],
    verbose = True
)

result = crew.kickoff()
print(result)
# Out:
# ╭──────────────────────────────────────────── Crew Execution Started ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: 1a736769-ced5-461d-9575-6e71d4186509                                                                       │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ...
